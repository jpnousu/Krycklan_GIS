# %%
import rasterio
import numpy as np
import os
from rasterio.mask import mask
from shapely.geometry import box
from rasterio.merge import merge
import matplotlib.pyplot as plt
from dotenv import load_dotenv

load_dotenv()
krycklan_data_path = os.getenv('KRYCKLAN_DATA_PATH')
krycklan_gis_data_path = os.getenv('KRYCKLAN_GIS_DATA_PATH')
print(f'Krycklan data path: {krycklan_data_path}')
print(f'Krycklan GIS data path: {krycklan_gis_data_path}')
# Out:
# Krycklan data path: /Users/jpnousu/Library/CloudStorage/OneDrive-Luonnonvarakeskus/Krycklan data
# Krycklan GIS data path: /Users/jpnousu/Data/Krycklan_GIS_data

# %%
# Catchment IDs
catchment_no = np.arange(1, 23)
exclude = [11, 17, 18, 19]
catchs = np.setdiff1d(catchment_no, exclude)

# Resolutions and vegetation types
resos = [20, 40, 80, 160]
trees = ['spruce', 'pine', 'decid']

# Base folders
ch_base = os.path.join(krycklan_data_path, 'GIS', 'FOREST_BASIC_KRYCKLAN', 'processed')
lai_base = os.path.join(krycklan_data_path, 'GIS', 'KRYCKLAN_LAI', 'processed')
cf_base = os.path.join(krycklan_data_path, 'GIS', 'SLU_FOREST_MAP_KRYCKLAN', '2010_processed')
soil_base = os.path.join(krycklan_data_path, 'GIS', 'SOIL', 'krycklan_QD')
soild_base = os.path.join(krycklan_data_path, 'GIS', 'SOIL', 'jorddjupsmodell', 'PROCESSED')

for reso in resos:
    # Define input file paths
    ch_path = os.path.join(ch_base, f'canopy_height_{reso}.asc')
    cf_path = os.path.join(cf_base, f'canopy_fraction_{reso}.asc')
    soil_path = os.path.join(soil_base, f'krycklan_QD_J1_J2_final_{reso}.asc')
    lake_path = os.path.join(soil_base, f'lake_mask_{reso}.asc')
    soild_path = os.path.join(soild_base, f'SOIL_DEPTH_{reso}.asc')
    lai_paths = [os.path.join(lai_base, f'LAI_{tree}_{reso}.asc') for tree in trees]
    files = [ch_path, cf_path, soil_path, lake_path, soild_path] + lai_paths

    for catch in catchs:
        ref_fp = os.path.join(krycklan_gis_data_path, f'{reso}m', f'C{catch}', 'cmask.asc')

        # Open reference cmask
        with rasterio.open(ref_fp) as ref_src:
            cmask = ref_src.read(1).astype("float32")
            bbox = box(*ref_src.bounds)
            shapes = [bbox]
            ref_meta = ref_src.meta.copy()

        for file in files:
            # Clean filename (strip resolution suffix)
            filename = os.path.basename(file)
            for r in resos:
                filename = filename.replace(f"_{r}", "")
            out_fp = os.path.join(os.path.dirname(ref_fp), filename)

            with rasterio.open(file) as src:
                try:
                    clipped_data, clipped_transform = mask(src, shapes, crop=True)
                except ValueError:
                    print(f"⚠️ Skipping empty intersection: {file} for catchment C{catch} ({reso}m)")
                    continue

                # Use first band (2D)
                clipped_band = clipped_data[0]

                # Crop cmask to same shape as clipped raster
                cmask_cropped = cmask[:clipped_band.shape[0], :clipped_band.shape[1]]

                # Apply mask: assign -9999 where cmask
                masked_data = np.where(np.isnan(cmask_cropped), -9999, clipped_band).astype("float32")
                masked_data = np.where(cmask_cropped == -9999, -9999, clipped_band).astype("float32")

                # Update metadata for single-band raster
                clipped_meta = src.meta.copy()
                clipped_meta.update({
                    "height": masked_data.shape[0],
                    "width": masked_data.shape[1],
                    "transform": clipped_transform,
                    "nodata": -9999,
                    "dtype": "float32",
                    "count": 1
                })

                # Write 2D array directly
                with rasterio.open(out_fp, 'w', **clipped_meta) as dst:
                    dst.write(masked_data, 1)

        print(f"✅ Clipped & masked: {filename}, C{catch} & {reso}m")
# Out:
# ✅ Clipped & masked: LAI_decid.asc, C1 & 20m
# ✅ Clipped & masked: LAI_decid.asc, C2 & 20m
# ✅ Clipped & masked: LAI_decid.asc, C3 & 20m
# ✅ Clipped & masked: LAI_decid.asc, C4 & 20m
# ✅ Clipped & masked: LAI_decid.asc, C5 & 20m
# ✅ Clipped & masked: LAI_decid.asc, C6 & 20m
# ✅ Clipped & masked: LAI_decid.asc, C7 & 20m
# ✅ Clipped & masked: LAI_decid.asc, C8 & 20m
# ✅ Clipped & masked: LAI_decid.asc, C9 & 20m
# ✅ Clipped & masked: LAI_decid.asc, C10 & 20m
# ✅ Clipped & masked: LAI_decid.asc, C12 & 20m
# ✅ Clipped & masked: LAI_decid.asc, C13 & 20m
# ✅ Clipped & masked: LAI_decid.asc, C14 & 20m
# ✅ Clipped & masked: LAI_decid.asc, C15 & 20m
# ✅ Clipped & masked: LAI_decid.asc, C16 & 20m
# ✅ Clipped & masked: LAI_decid.asc, C20 & 20m
# ✅ Clipped & masked: LAI_decid.asc, C21 & 20m
# ✅ Clipped & masked: LAI_decid.asc, C22 & 20m
# ✅ Clipped & masked: LAI_decid.asc, C1 & 40m
# ✅ Clipped & masked: LAI_decid.asc, C2 & 40m
# ✅ Clipped & masked: LAI_decid.asc, C3 & 40m
# ✅ Clipped & masked: LAI_decid.asc, C4 & 40m
# ✅ Clipped & masked: LAI_decid.asc, C5 & 40m
# ✅ Clipped & masked: LAI_decid.asc, C6 & 40m
# ✅ Clipped & masked: LAI_decid.asc, C7 & 40m
# ✅ Clipped & masked: LAI_decid.asc, C8 & 40m
# ✅ Clipped & masked: LAI_decid.asc, C9 & 40m
# ✅ Clipped & masked: LAI_decid.asc, C10 & 40m
# ✅ Clipped & masked: LAI_decid.asc, C12 & 40m
# ✅ Clipped & masked: LAI_decid.asc, C13 & 40m
# ✅ Clipped & masked: LAI_decid.asc, C14 & 40m
# ✅ Clipped & masked: LAI_decid.asc, C15 & 40m
# ✅ Clipped & masked: LAI_decid.asc, C16 & 40m
# ✅ Clipped & masked: LAI_decid.asc, C20 & 40m
# ✅ Clipped & masked: LAI_decid.asc, C21 & 40m
# ✅ Clipped & masked: LAI_decid.asc, C22 & 40m
# ✅ Clipped & masked: LAI_decid.asc, C1 & 80m
# ✅ Clipped & masked: LAI_decid.asc, C2 & 80m
# ✅ Clipped & masked: LAI_decid.asc, C3 & 80m
# ✅ Clipped & masked: LAI_decid.asc, C4 & 80m
# ✅ Clipped & masked: LAI_decid.asc, C5 & 80m
# ✅ Clipped & masked: LAI_decid.asc, C6 & 80m
# ✅ Clipped & masked: LAI_decid.asc, C7 & 80m
# ✅ Clipped & masked: LAI_decid.asc, C8 & 80m
# ✅ Clipped & masked: LAI_decid.asc, C9 & 80m
# ✅ Clipped & masked: LAI_decid.asc, C10 & 80m
# ✅ Clipped & masked: LAI_decid.asc, C12 & 80m
# ✅ Clipped & masked: LAI_decid.asc, C13 & 80m
# ✅ Clipped & masked: LAI_decid.asc, C14 & 80m
# ✅ Clipped & masked: LAI_decid.asc, C15 & 80m
# ✅ Clipped & masked: LAI_decid.asc, C16 & 80m
# ✅ Clipped & masked: LAI_decid.asc, C20 & 80m
# ✅ Clipped & masked: LAI_decid.asc, C21 & 80m
# ✅ Clipped & masked: LAI_decid.asc, C22 & 80m
# ✅ Clipped & masked: LAI_decid.asc, C1 & 160m
# ✅ Clipped & masked: LAI_decid.asc, C2 & 160m
# ✅ Clipped & masked: LAI_decid.asc, C3 & 160m
# ✅ Clipped & masked: LAI_decid.asc, C4 & 160m
# ✅ Clipped & masked: LAI_decid.asc, C5 & 160m
# ✅ Clipped & masked: LAI_decid.asc, C6 & 160m
# ✅ Clipped & masked: LAI_decid.asc, C7 & 160m
# ✅ Clipped & masked: LAI_decid.asc, C8 & 160m
# ✅ Clipped & masked: LAI_decid.asc, C9 & 160m
# ✅ Clipped & masked: LAI_decid.asc, C10 & 160m
# ✅ Clipped & masked: LAI_decid.asc, C12 & 160m
# ✅ Clipped & masked: LAI_decid.asc, C13 & 160m
# ✅ Clipped & masked: LAI_decid.asc, C14 & 160m
# ✅ Clipped & masked: LAI_decid.asc, C15 & 160m
# ✅ Clipped & masked: LAI_decid.asc, C16 & 160m
# ✅ Clipped & masked: LAI_decid.asc, C20 & 160m
# ✅ Clipped & masked: LAI_decid.asc, C21 & 160m
# ✅ Clipped & masked: LAI_decid.asc, C22 & 160m

# %%
# Root directory (base path without resolution)
root_base = krycklan_gis_data_path
resos = [20, 40, 80, 160]  # resolutions to loop over

for reso in resos:
    #print(f"\n=== Processing {reso}m resolution ===")

    root_dir = os.path.join(root_base, f"{reso}m")
    all_dir = os.path.join(root_dir, "ALL")
    os.makedirs(all_dir, exist_ok=True)

    # Get subcatchment directories (C1..CX)
    subcatchments = [d for d in os.listdir(root_dir) 
                     if os.path.isdir(os.path.join(root_dir, d)) and d.startswith("C")]

    if not subcatchments:
        raise RuntimeError(f"No subcatchment folders found in {root_dir}!")

    # Use first catchment to determine which .asc files to mosaic
    sample_dir = os.path.join(root_dir, subcatchments[0])
    asc_files = [f for f in os.listdir(sample_dir) if f.endswith(".asc")]

    for asc_file in asc_files:
        # Collect paths for this file across all subcatchments
        asc_paths = []
        for sub in subcatchments:
            candidate = os.path.join(root_dir, sub, asc_file)
            if os.path.exists(candidate):
                asc_paths.append(candidate)

        if not asc_paths:
            print(f"  ⚠️ Skipping {asc_file} (not found in any subcatchment)")
            continue

        # Strip CRS from each file before merging to avoid rasterio.merge
        # CRS mismatch caused by inconsistent .prj sidecars across .asc files
        for p in asc_paths:
            with rasterio.open(p) as src:
                data = src.read(1)
                profile = src.profile.copy()
            profile.update(crs=None)
            with rasterio.open(p, 'w', **profile) as dst:
                dst.write(data, 1)

        # Open all rasters
        src_files_to_mosaic = [rasterio.open(p) for p in asc_paths]

        # Merge rasters
        mosaic, out_transform = merge(src_files_to_mosaic)

        # Copy metadata
        out_meta = src_files_to_mosaic[0].meta.copy()
        out_meta.update({
            "driver": "AAIGrid",      # keep ASCII grid format
            "height": mosaic.shape[1],
            "width": mosaic.shape[2],
            "transform": out_transform,
            "nodata": -9999,
            "dtype": "float32",
            "count": 1
        })

        # Replace any nodata with -9999
        data = np.where(mosaic == out_meta.get("nodata", None), -9999, mosaic).astype("float32")

        # Output path in ALL
        out_path = os.path.join(all_dir, asc_file)

        # Save as ASC
        with rasterio.open(out_path, "w", **out_meta) as dest:
            dest.write(data)

        for src in src_files_to_mosaic:
            src.close()

# %%
import os
import rasterio
import numpy as np

# Config
resos = [20, 40, 80, 160]
species = ['spruce', 'decid', 'pine']
nodata_out = -9999.0
propagate_any_nodata = False  # If True -> output nodata where ANY species is nodata

for reso in resos:
    #print(f"\n▶ Processing LAI total for {reso}m ...")

    # Build paths
    lai_paths = [
        os.path.join(krycklan_gis_data_path, f'{reso}m', 'ALL', f'LAI_{specie}.asc')
        for specie in species
    ]

    data_list = []
    valid_masks = []
    meta = None

    # Read species rasters
    for fp in lai_paths:
        if not os.path.exists(fp):
            raise FileNotFoundError(f"Missing LAI file: {fp}")

        with rasterio.open(fp) as src:
            arr = src.read(1).astype("float32")
            src_nodata = src.nodata if src.nodata is not None else nodata_out

            # Build valid-data mask
            valid = arr != src_nodata

            # For summing, treat nodata as 0.0
            arr_filled = np.where(valid, arr, 0.0).astype("float32")

            data_list.append(arr_filled)
            valid_masks.append(valid)

            # Save metadata from first raster
            if meta is None:
                meta = src.meta.copy()

    if meta is None:
        print(f"  ⚠️ No metadata found for {reso}m — skipping")
        continue

    # Sanity check: ensure all arrays have same shape
    shapes = {d.shape for d in data_list}
    if len(shapes) != 1:
        raise RuntimeError(f"Input LAI rasters for {reso}m have different shapes: {shapes}")

    # Sum species (nodata treated as 0 for sum)
    lai_total = np.sum(data_list, axis=0).astype("float32")

    # Determine where output should be nodata
    if propagate_any_nodata:
        # nodata where any species is nodata (strict propagation)
        any_nodata_mask = np.logical_not(np.logical_and.reduce(valid_masks))
        out_mask_nodata = any_nodata_mask
    else:
        # nodata only where ALL species are nodata (i.e. no data anywhere)
        any_valid = np.logical_or.reduce(valid_masks)
        out_mask_nodata = np.logical_not(any_valid)

    # Assign nodata_out where masked
    lai_total = np.where(out_mask_nodata, nodata_out, lai_total).astype("float32")

    # Update metadata for single-band output ASCII
    meta.update({
        "dtype": "float32",
        "nodata": nodata_out,
        "count": 1,
        "driver": "AAIGrid"
    })

    out_fp = os.path.join(krycklan_gis_data_path, f'{reso}m', 'ALL', 'LAI_tot.asc')
    with rasterio.open(out_fp, "w", **meta) as dst:
        dst.write(lai_total, 1)

    #print(f"  ✅ Saved LAI total: {out_fp}")

# %%
# Config
resos = [20, 40, 80, 160]
species = ['spruce', 'decid', 'pine']
nodata_out = -9999.0
propagate_any_nodata = False  # If True -> output nodata where ANY species is nodata

for reso in resos:
    print(f"\n▶ Processing LAI rasters for {reso}m ...")

    # Build paths for all species
    lai_paths = {
        specie: os.path.join(krycklan_gis_data_path, f'{reso}m', 'ALL', f'LAI_{specie}.asc')
        for specie in species
    }

    data_dict = {}
    valid_dict = {}
    meta = None

    # Read species rasters
    for specie, fp in lai_paths.items():
        if not os.path.exists(fp):
            raise FileNotFoundError(f"Missing LAI file: {fp}")

        with rasterio.open(fp) as src:
            arr = src.read(1).astype("float32")
            src_nodata = src.nodata if src.nodata is not None else nodata_out

            # Build valid-data mask
            valid = arr != src_nodata

            # For summing, treat nodata as 0.0
            arr_filled = np.where(valid, arr, 0.0).astype("float32")

            data_dict[specie] = arr_filled
            valid_dict[specie] = valid

            # Save metadata from first raster
            if meta is None:
                meta = src.meta.copy()

    if meta is None:
        print(f"  ⚠️ No metadata found for {reso}m — skipping")
        continue

    # Sanity check: ensure all arrays have same shape
    shapes = {arr.shape for arr in data_dict.values()}
    if len(shapes) != 1:
        raise RuntimeError(f"Input LAI rasters for {reso}m have different shapes: {shapes}")

    # Read cmask from ALL directory
    cmask_fp = os.path.join(krycklan_gis_data_path, f'{reso}m', 'ALL', 'cmask.asc')
    with rasterio.open(cmask_fp) as src:
        cmask_all = src.read(1).astype("float32")

    # --- Compute LAI totals ---
    lai_total = (data_dict['spruce'] + data_dict['pine'] + data_dict['decid']).astype("float32")
    lai_conif = (data_dict['spruce'] + data_dict['pine']).astype("float32")

    # Apply cmask: -9999 outside catchment (cmask != 1)
    lai_total = np.where(cmask_all != -9999, lai_total, nodata_out).astype("float32")
    lai_conif = np.where(cmask_all != -9999, lai_conif, nodata_out).astype("float32")

    # Update metadata for single-band output ASCII
    meta.update({
        "dtype": "float32",
        "nodata": nodata_out,
        "count": 1,
        "driver": "AAIGrid"
    })

    # Write outputs
    out_total = os.path.join(krycklan_gis_data_path, f'{reso}m', 'ALL', 'LAI_tot.asc')
    out_conif = os.path.join(krycklan_gis_data_path, f'{reso}m', 'ALL', 'LAI_conif.asc')

    with rasterio.open(out_total, "w", **meta) as dst:
        dst.write(lai_total, 1)
    with rasterio.open(out_conif, "w", **meta) as dst:
        dst.write(lai_conif, 1)

    print(f"  ✅ Saved: {out_total}")
    print(f"  ✅ Saved: {out_conif}")
# Out:
# ▶ Processing LAI rasters for 20m ...
#   ✅ Saved: /Users/jpnousu/Data/Krycklan_GIS_data/20m/ALL/LAI_tot.asc
#   ✅ Saved: /Users/jpnousu/Data/Krycklan_GIS_data/20m/ALL/LAI_conif.asc
#
# ▶ Processing LAI rasters for 40m ...
#   ✅ Saved: /Users/jpnousu/Data/Krycklan_GIS_data/40m/ALL/LAI_tot.asc
#   ✅ Saved: /Users/jpnousu/Data/Krycklan_GIS_data/40m/ALL/LAI_conif.asc
#
# ▶ Processing LAI rasters for 80m ...
#   ✅ Saved: /Users/jpnousu/Data/Krycklan_GIS_data/80m/ALL/LAI_tot.asc
#   ✅ Saved: /Users/jpnousu/Data/Krycklan_GIS_data/80m/ALL/LAI_conif.asc
#
# ▶ Processing LAI rasters for 160m ...
#   ✅ Saved: /Users/jpnousu/Data/Krycklan_GIS_data/160m/ALL/LAI_tot.asc
#   ✅ Saved: /Users/jpnousu/Data/Krycklan_GIS_data/160m/ALL/LAI_conif.asc
